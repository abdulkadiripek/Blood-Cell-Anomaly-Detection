# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("blood_cell_anomaly_detection.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5880 entries, 0 to 5879
# Data columns (total 36 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   cell_id                                  5880 non-null   object
#  1   cell_type                                5880 non-null   object
#  2   anomaly_label                            5880 non-null   int64
#  3   disease_category                         5880 non-null   object
#  4   cell_diameter_um                         5880 non-null   float64
#  5   nucleus_area_pct                         5880 non-null   float64
#  6   chromatin_density                        5880 non-null   float64
#  7   cytoplasm_ratio                          5880 non-null   float64
#  8   circularity                              5880 non-null   float64
#  9   eccentricity                             5880 non-null   float64
# ...

# %%
df.describe()
# Out:
#        anomaly_label  cell_diameter_um  nucleus_area_pct  chromatin_density  \
# count    5880.000000       5880.000000       5880.000000        5880.000000
# mean        0.319728         10.176267         43.537976           0.391394
# std         0.466411          3.642051         33.419390           0.310006
# min         0.000000          1.000000          0.000000           0.000000
# 25%         0.000000          7.630000          0.000000           0.000000
# 50%         0.000000         10.055000         54.500000           0.479500
# 75%         1.000000         12.860000         72.300000           0.635000
# max         1.000000         21.180000         99.000000           1.000000
#
#        cytoplasm_ratio  circularity  eccentricity  granularity_score  \
# count      5880.000000  5880.000000   5880.000000        5880.000000
# mean          0.564173     0.769263      0.365458           1.882109
# std           0.335282     0.158219      0.201501           1.428336
# ...

# %%
df.head()
# Out:
#        cell_id                  cell_type  anomaly_label disease_category  \
# 0  CELL_005371  Hypersegmented_Neutrophil              1        Infection
# 1  CELL_005300  Hypersegmented_Neutrophil              1        Infection
# 2  CELL_000200                 Neutrophil              0       Normal_WBC
# 3  CELL_003269                 Normal_RBC              0       Normal_RBC
# 4  CELL_003505                 Normal_RBC              0       Normal_RBC
#
#    cell_diameter_um  nucleus_area_pct  chromatin_density  cytoplasm_ratio  \
# 0             15.18              58.8              0.542            0.301
# 1             16.47              73.6              0.583            0.365
# 2             13.41              55.5              0.448            0.376
# 3              7.36               0.0              0.000            1.000
# 4              7.53               0.0              0.000            1.000
#
#    circularity  eccentricity  ...  mcv_fl  mchc_g_dl  dataset_source  \
# ...

# %%
df["disease_category"].value_counts()
# Out:
# disease_category
# Normal_WBC            2800
# Normal_RBC             900
# Anemia                 650
# Leukemia               460
# Infection              450
# Normal_Platelet        300
# Artefact               180
# Sickle_Cell_Anemia     140
# Name: count, dtype: int64

# %%
# Burada önemsiz column'ların listesini çıkartıyoruz.
unimportant_columns = [
    'cell_id', 'anomaly_label', 'mean_r', 'mean_g', 'mean_b', 
    'stain_intensity', 'dataset_source', 'staining_protocol', 
    'microscope_model', 'magnification_x', 'image_resolution_px',
    'cytodiffusion_anomaly_score', 'cytodiffusion_classification_confidence',
    'labeller_confidence_score'
]

# %%
#Burda da dropluyoruz.
df.drop(unimportant_columns, inplace=True,axis=1)

# %%
sns.scatterplot(
    data = df,
    x = df["nucleus_area_pct"] ,
    y = df["cell_diameter_um"] ,
    hue = df["disease_category"],
    alpha = 0.7
)
plt.title("Hücre çekirdek ve çap oranı.")
plt.xlabel("Çekirdek / Tüm Hücre")
plt.ylabel("Hücre Yarıçağı (mikrometre)")
plt.show()

# %%
df.head()
# Out:
#                    cell_type disease_category  cell_diameter_um  \
# 0  Hypersegmented_Neutrophil        Infection             15.18
# 1  Hypersegmented_Neutrophil        Infection             16.47
# 2                 Neutrophil       Normal_WBC             13.41
# 3                 Normal_RBC       Normal_RBC              7.36
# 4                 Normal_RBC       Normal_RBC              7.53
#
#    nucleus_area_pct  chromatin_density  cytoplasm_ratio  circularity  \
# 0              58.8              0.542            0.301        0.563
# 1              73.6              0.583            0.365        0.859
# 2              55.5              0.448            0.376        0.781
# 3               0.0              0.000            1.000        0.880
# 4               0.0              0.000            1.000        1.000
#
#    eccentricity  granularity_score  lobularity_score  ...  perimeter_px  \
# 0         0.529               4.11               6.6  ...            90
# ...

# %%
y = df["disease_category"].values

# %%
df = df.drop("disease_category",axis=1)
df
# Out:
#                       cell_type  cell_diameter_um  nucleus_area_pct  \
# 0     Hypersegmented_Neutrophil             15.18              58.8
# 1     Hypersegmented_Neutrophil             16.47              73.6
# 2                    Neutrophil             13.41              55.5
# 3                    Normal_RBC              7.36               0.0
# 4                    Normal_RBC              7.53               0.0
# ...                         ...               ...               ...
# 5875                   Platelet              2.30               0.0
# 5876                Target_Cell              8.80               0.0
# 5877                Target_Cell              9.57               0.0
# 5878  Hypersegmented_Neutrophil             11.98              67.8
# 5879                 Neutrophil             12.58              51.0
#
#       chromatin_density  cytoplasm_ratio  circularity  eccentricity  \
# 0                 0.542            0.301        0.563         0.529
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_y = LabelEncoder()
y = le_y.fit_transform(y)
y
# Out:
# array([2, 2, 6, ..., 0, 2, 6], shape=(5880,))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5880 entries, 0 to 5879
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   cell_type                  5880 non-null   object
#  1   cell_diameter_um           5880 non-null   float64
#  2   nucleus_area_pct           5880 non-null   float64
#  3   chromatin_density          5880 non-null   float64
#  4   cytoplasm_ratio            5880 non-null   float64
#  5   circularity                5880 non-null   float64
#  6   eccentricity               5880 non-null   float64
#  7   granularity_score          5880 non-null   float64
#  8   lobularity_score           5880 non-null   float64
#  9   membrane_smoothness        5880 non-null   float64
#  10  cell_area_px               5880 non-null   int64
#  11  perimeter_px               5880 non-null   int64
#  12  patient_age_group          5880 non-null   object
# ...

# %%
df["patient_age_group"].value_counts()
# Out:
# patient_age_group
# Adult        3276
# Elderly      1455
# Pediatric    1149
# Name: count, dtype: int64

# %%
age_mapping = {
    'Pediatric': 0,
    'Adult'    : 1,
    'Elderly'  : 2,
}
df['patient_age_group'] = df['patient_age_group'].map(age_mapping)

# %%
object_columns = df.select_dtypes(include='object').columns

# %%
for i in object_columns:
    df[i] = le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5880 entries, 0 to 5879
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   cell_type                  5880 non-null   int64
#  1   cell_diameter_um           5880 non-null   float64
#  2   nucleus_area_pct           5880 non-null   float64
#  3   chromatin_density          5880 non-null   float64
#  4   cytoplasm_ratio            5880 non-null   float64
#  5   circularity                5880 non-null   float64
#  6   eccentricity               5880 non-null   float64
#  7   granularity_score          5880 non-null   float64
#  8   lobularity_score           5880 non-null   float64
#  9   membrane_smoothness        5880 non-null   float64
#  10  cell_area_px               5880 non-null   int64
#  11  perimeter_px               5880 non-null   int64
#  12  patient_age_group          5880 non-null   int64
# ...

# %%
x = df.values
x
# Out:
# array([[5.00000e+00, 1.51800e+01, 5.88000e+01, ..., 2.57383e+05,
#         8.55000e+01, 3.14000e+01],
#        [5.00000e+00, 1.64700e+01, 7.36000e+01, ..., 3.02274e+05,
#         9.25000e+01, 3.50000e+01],
#        [8.00000e+00, 1.34100e+01, 5.55000e+01, ..., 2.29996e+05,
#         7.63000e+01, 3.30000e+01],
#        ...,
#        [1.70000e+01, 9.57000e+00, 0.00000e+00, ..., 2.93938e+05,
#         8.67000e+01, 3.40000e+01],
#        [5.00000e+00, 1.19800e+01, 6.78000e+01, ..., 2.98582e+05,
#         9.65000e+01, 3.29000e+01],
#        [8.00000e+00, 1.25800e+01, 5.10000e+01, ..., 3.06735e+05,
#         8.27000e+01, 3.25000e+01]], shape=(5880, 21))

# %%
x_train, x_test, y_train, y_test, = train_test_split(x,y,train_size=0.8,random_state=42,stratify=y)

# %%
# Tutarsız verileri daha tutarlı hale getiriyoruz.
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train) # x_train üzerinde öğren ve uygula
x_test = scaler.transform(x_test) # x_test üzerinde uygula

# %%
x_train = torch.tensor(x_train, dtype=torch.float32)
x_test = torch.tensor(x_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.long)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# torch.Size([4704, 21]) torch.Size([1176, 21]) torch.Size([4704]) torch.Size([1176])

# %%
class BloodClassification(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_layer_stack = nn.Sequential(
            nn.Linear(21,25),
            nn.GELU(),
            nn.Linear(25,25),
            nn.GELU(),
            nn.Linear(25,8)
        )
    def forward(self, x):
        return self.linear_layer_stack(x)

# %%
model = BloodClassification()

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr= 0.001)

# %%
from torchmetrics.classification import MulticlassAccuracy

# %%
accuracy = MulticlassAccuracy(num_classes=8)

# %%
epochs = 500

for epoch in range(epochs):
    model.train() #Train modunu başlatıyoruz.
    
    logits = model(x_train) #modelimize öncelikle tahminde bulunduruyoruz.
    loss = loss_fn(logits,y_train) # Loss Func. ile hatayı hesaplıyoruz.
    pred = torch.softmax(logits,dim=1).argmax(dim=1) # Softmax ile bir çıktı alıyoıruz.
    acc = accuracy(pred,y_train) * 100 # Doğruluğuna bakıyoruz.

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    model.eval() # Test moduna alıyoruz.
    with torch.inference_mode():
        test_logits = model(x_test)
        test_loss = loss_fn(test_logits,y_test)
        test_pred = torch.softmax(test_logits, dim=1).argmax(dim=1)
        test_acc = accuracy(test_pred,y_test) * 100
    if epoch % 25 == 0:
        print(f"Epoch:{epoch}, Loss:{loss}, Acc:{acc}")
        print(f"Epoch:{epoch}, Test_Loss:{test_loss}, Test_Acc:{test_acc}")
        print("-----------------------------")
# Out:
# Epoch:0, Loss:2.0174527168273926, Acc:13.140602111816406
# Epoch:0, Test_Loss:2.011322021484375, Test_Acc:13.030878067016602
# -----------------------------
# Epoch:25, Loss:1.8268399238586426, Acc:25.50109100341797
# Epoch:25, Test_Loss:1.8191438913345337, Test_Acc:26.17219352722168
# -----------------------------
# Epoch:50, Loss:1.4889477491378784, Acc:31.5638370513916
# Epoch:50, Test_Loss:1.4739497900009155, Test_Acc:30.6036319732666
# -----------------------------
# Epoch:75, Loss:1.0811282396316528, Acc:32.69230651855469
# Epoch:75, Test_Loss:1.0690094232559204, Test_Acc:32.16880416870117
# -----------------------------
# Epoch:100, Loss:0.7951632142066956, Acc:41.53410720825195
# Epoch:100, Test_Loss:0.7913973927497864, Test_Acc:41.089046478271484
# -----------------------------
# Epoch:125, Loss:0.5913674235343933, Acc:59.60586166381836
# Epoch:125, Test_Loss:0.5952410697937012, Test_Acc:59.857810974121094
# -----------------------------
# ...

# %%
from torchmetrics.classification import ConfusionMatrix
from torchmetrics.utilities import plot

# %%
cm = ConfusionMatrix(task='multiclass', num_classes=8)
matrix = cm(test_pred,y_test)
matrix = matrix.numpy()
plt.figure(figsize=(10, 8))
sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
from pathlib import Path

# %%
MODEL_PATH = Path("models")
MODEL_PATH.mkdir(parents=True,exist_ok = True)

MODEL_NAME = "Blood_Cell_Anomaly_Detection.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME
print(MODEL_SAVE_PATH)
# Out:
# models/Blood_Cell_Anomaly_Detection.pth

# %%
torch.save(model.state_dict(),f=MODEL_SAVE_PATH)

# %%
model.state_dict()
# Out:
# OrderedDict([('linear_layer_stack.0.weight',
#               tensor([[-1.9680e-01, -1.7147e-01,  2.6824e-01,  2.9344e-01,  1.5871e-02,
#                         6.7479e-02, -1.1252e-01,  3.4842e-01, -1.0194e-01, -2.7116e-01,
#                        -1.8886e-02, -1.1801e-01, -1.8532e-01, -3.1766e-01,  1.9113e-01,
#                        -6.6554e-02, -1.5729e-01,  3.6052e-01, -5.7143e-02,  1.4656e-01,
#                        -1.6730e-01],
#                       [ 5.0669e-01, -2.4206e-01, -3.3070e-01, -1.9118e-02,  2.4062e-01,
#                         1.4436e-01, -8.9110e-02, -3.6823e-01, -3.4620e-02,  2.6378e-01,
#                        -1.5235e-01, -2.8206e-01, -8.9460e-02,  1.3386e-01,  1.2094e-01,
#                         1.1880e-01,  2.8405e-01, -1.5471e-01, -1.3191e-01, -2.9250e-01,
#                         1.5980e-01],
#                       [ 6.6523e-02,  2.6169e-01,  3.9655e-01, -1.8883e-01, -1.5190e-01,
# ...

# %%
loaded_model = BloodClassification()

# %%
loaded_model.load_state_dict(torch.load(MODEL_SAVE_PATH))
# Out:
# <All keys matched successfully>

# %%
new_list = np.array([[-0.5237,  0.4989,  1.3398,  1.2905, -0.8759,  0.0997, -0.5493, -0.4358,
        -0.5431,  0.4886, -0.2347, -0.0607, -0.0428, -0.9869,  1.3690, -1.6914,
        -0.1710,  0.1542, -0.0940,  0.4668,  0.2366]])

# %%
new_list = torch.tensor(new_list , dtype=torch.float32)

# %%
loaded_model.eval()
with torch.inference_mode():
    logit = loaded_model(new_list)
    probs = torch.softmax(logit,dim=1)
    predicted_class = torch.argmax(probs,dim=1).item()

# %%
print(f"Modelin tahmin ettiği indeks: {predicted_class}")
print(f"LabelEncoder'daki toplam sınıf sayısı: {len(le_y.classes_)}")
print(f"Mevcut sınıflar: {le_y.classes_}")
# Out:
# Modelin tahmin ettiği indeks: 6
# LabelEncoder'daki toplam sınıf sayısı: 8
# Mevcut sınıflar: ['Anemia' 'Artefact' 'Infection' 'Leukemia' 'Normal_Platelet' 'Normal_RBC'
#  'Normal_WBC' 'Sickle_Cell_Anemia']

# %%
le_y.inverse_transform([predicted_class]).item()
# Out:
# 'Normal_WBC'
